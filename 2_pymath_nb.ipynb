# %%
import numpy as np
from sympy import *
from sympy.plotting import plot

init_printing()

# %%
var('p, q, r, x, y')
var('α, β, γ')
# Out:
# (α, β, γ)

# %%
p = plot( 
        2-r, 
        3*(1-r), 
        xlim = (0, 1), ylim = (0, 5),
        legend = True, show = False)
p[0].line_color = 'b'
p[1].line_color = 'r'
p.show()
